# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
# create df
train = pd.read_csv('C:/Users/Sanjay/3datascienceprojects/flaskMLdemo/flask-app/titanic.csv') # change file path
# drop null values
train.dropna(inplace=True)
# features and target
target = 'Survived'
features = ['Pclass', 'Age', 'SibSp', 'Fare']
# X matrix, y vector
X = train[features]
y = train[target]
# model 
model = LogisticRegression()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.7103825136612022

# %%
import pickle

# %%
import pickle
pickle.dump(model, open('model.pkl', 'wb'))

# %%
#a=pd.read_pickle('model.pkl')
#print(a)
# Out:
# LogisticRegression()

# %%
import requests, json

# %%
# local url
url = 'http://127.0.0.1:5000' # change to your url

# %%
# sample data
data = {'Pclass': 3
      , 'Age': 2
      , 'SibSp': 1
      , 'Fare': 50}
data = json.dumps(data)

# %%
send_request=requests.post(url, data)
print(send_request)
# Out:
# <Response [200]>

# %%
print(send_request.json())
# Out:
# {'results': {'results': 1}}

# %%
pip freeze
# Out:
# - @ file:///C:/ci/scikit-learn_1592853510272/work
# -cikit-learn @ file:///C:/ci/scikit-learn_1592853510272/work
# afinn==0.1
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.10.0
# anaconda-project==0.8.3
# appdirs @ file:///home/conda/feedstock_root/build_artifacts/appdirs_1603108395799/work
# argh @ file:///home/conda/feedstock_root/build_artifacts/argh_1595627874344/work
# argon2-cffi @ file:///D:/bld/argon2-cffi_1605217273648/work
# arrow @ file:///D:/bld/arrow_1602526996468/work
# asn1crypto @ file:///home/conda/feedstock_root/build_artifacts/asn1crypto_1595949944546/work
# astroid==2.4.2
# astropy @ file:///D:/bld/astropy_1606674849979/work
# async-generator==1.10
# atomicwrites @ file:///home/conda/feedstock_root/build_artifacts/atomicwrites_1588182545583/work
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1605083924122/work
# autopep8==1.5.4
# Babel @ file:///home/conda/feedstock_root/build_artifacts/babel_1605182336601/work
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache==1.6.1
# backports.shutil-get-terminal-size==1.0.0
# bayesian-optimization==1.2.0
# bcrypt @ file:///D:/bld/bcrypt_1602547008978/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1601745390275/work
# binaryornot==0.4.4
# bitarray @ file:///D:/bld/bitarray_1604785524866/work
# bkcharts==0.2
# black @ file:///home/conda/feedstock_root/build_artifacts/black-recipe_1599478779128/work
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1600454382015/work
# blis @ file:///D:/bld/cython-blis_1607338345852/work
# bokeh @ file:///D:/bld/bokeh_1606141542919/work
# boto==2.49.0
# boto3==1.14.47
# botocore==1.17.47
# Bottleneck @ file:///D:/bld/bottleneck_1602497497821/work
# brotlipy==0.7.0
# cached-property==1.5.1
# camelot-py @ file:///home/conda/feedstock_root/build_artifacts/camelot-py_1597402131245/work
# catalogue @ file:///D:/bld/catalogue_1605613788233/work
# catboost==0.24.1
# Note: you may need to restart the kernel to use updated packages.category-encoders==2.2.2
#
# cauldron-notebook==1.0.5
# certifi==2020.12.5
# cffi @ file:///D:/bld/cffi_1606601395031/work
# chardet @ file:///D:/bld/chardet_1602255508636/work
# click==7.1.2
# cloudpickle @ file:///home/conda/feedstock_root/build_artifacts/cloudpickle_1598400192773/work
# clyent==1.2.2
# colorama==0.4.3
# comtypes==1.1.7
# conda==4.9.2
# conda-build==3.20.5
# conda-package-handling @ file:///D:/bld/conda-package-handling_1602877082869/work
# conda-verify @ file:///D:/bld/conda-verify_1603158504992/work
# confuse==1.3.0
# contextlib2==0.6.0.post1
# cookiecutter==1.7.2
# cryptography @ file:///D:/bld/cryptography_1607606432554/work
# cycler==0.10.0
# cymem @ file:///D:/bld/cymem_1607336390769/work
# Cython==0.29.14
# cytoolz==0.11.0
# dask @ file:///home/conda/feedstock_root/build_artifacts/dask-core_1607657054678/work
# decorator==4.4.2
# defusedxml==0.6.0
# diff-match-patch @ file:///home/conda/feedstock_root/build_artifacts/diff-match-patch_1594679019945/work
# distributed @ file:///D:/bld/distributed_1607664133003/work
# docutils==0.15.2
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1605121927639/work/dist/entrypoints-0.3-py2.py3-none-any.whl
# et-xmlfile==1.0.1
# fastcache @ file:///D:/bld/fastcache_1605447373430/work
# filelock @ file:///home/conda/feedstock_root/build_artifacts/filelock_1589994591731/work
# flake8 @ file:///home/conda/feedstock_root/build_artifacts/flake8_1601874335748/work
# Flask==1.1.2
# fsspec @ file:///home/conda/feedstock_root/build_artifacts/fsspec_1602700749102/work
# future @ file:///D:/bld/future_1605203720223/work
# gensim==3.8.3
# gevent @ file:///D:/bld/gevent_1602543259420/work
# ghostscript==0.6
# gitdb @ file:///home/conda/feedstock_root/build_artifacts/gitdb_1588651542737/work
# GitPython @ file:///home/conda/feedstock_root/build_artifacts/gitpython_1603460643560/work
# glob2==0.7
# gmpy2==2.1.0b1
# graphviz==0.14.1
# greenlet @ file:///D:/bld/greenlet_1602289380281/work
# gunicorn==20.0.4
# h5py @ file:///D:/bld/h5py_1604753864980/work
# HeapDict==1.0.1
# helpdev @ file:///home/conda/feedstock_root/build_artifacts/helpdev_1604871301491/work
# html5lib @ file:///home/conda/feedstock_root/build_artifacts/html5lib_1592930327044/work
# htmlmin==0.1.12
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1593328102638/work
# imagecodecs @ file:///D:/bld/imagecodecs_1607400615884/work
# ImageHash==4.1.0
# imageio @ file:///home/conda/feedstock_root/build_artifacts/imageio_1594044661732/work
# imagesize==1.2.0
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1606885585839/work
# iniconfig @ file:///home/conda/feedstock_root/build_artifacts/iniconfig_1603384189793/work
# intervaltree==3.0.2
# ipykernel @ file:///D:/bld/ipykernel_1607737448354/work/dist/ipykernel-5.4.2-py3-none-any.whl
# ipython @ file:///D:/bld/ipython_1604159844946/work
# ipython-genutils==0.2.0
# ipywidgets @ file:///home/conda/feedstock_root/build_artifacts/ipywidgets_1599554010055/work
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi @ file:///D:/bld/jedi_1605054817163/work
# Jinja2==2.11.2
# jinja2-time==0.2.0
# jmespath==0.10.0
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1601671685479/work
# json5 @ file:///home/conda/feedstock_root/build_artifacts/json5_1600692310011/work
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema_1602551949684/work
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1598486169312/work
# jupyter-console @ file:///home/conda/feedstock_root/build_artifacts/jupyter_console_1598728807792/work
# jupyter-core @ file:///D:/bld/jupyter_core_1605735280365/work
# jupyterlab==2.2.9
# jupyterlab-git @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab-git_1606401921342/work
# jupyterlab-pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1601375948261/work
# jupyterlab-server @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_server_1593951277307/work
# keyring @ file:///D:/bld/keyring_1605211465804/work
# kiwisolver @ file:///D:/bld/kiwisolver_1604322452227/work
# lazy-object-proxy==1.4.3
# libarchive-c @ file:///D:/bld/python-libarchive-c_1602422843138/work
# lightgbm==2.3.1
# llvmlite==0.35.0
# locket==0.2.0
# lxml @ file:///D:/bld/lxml_1606483759944/work
# Markdown @ file:///home/conda/feedstock_root/build_artifacts/markdown_1603668500820/work
# MarkupSafe @ file:///D:/bld/markupsafe_1602267501600/work
# matplotlib @ file:///D:/bld/matplotlib-suite_1605180506412/work
# mccabe==0.6.1
# menuinst @ file:///D:/bld/menuinst_1602541318140/work
# missingno==0.4.2
# mistune @ file:///D:/bld/mistune_1605115857778/work
# mkl-fft==1.2.0
# mkl-random==1.2.0
# mkl-service==2.3.0
# mock @ file:///D:/bld/mock_1607640093411/work
# more-itertools @ file:///home/conda/feedstock_root/build_artifacts/more-itertools_1604071731434/work
# mpmath==1.1.0
# msgpack @ file:///D:/bld/msgpack-python_1607693709728/work
# multipledispatch==0.6.0
# murmurhash @ file:///D:/bld/murmurhash_1607334400096/work
# mypy-extensions @ file:///D:/bld/mypy_extensions_1607883378293/work
# navigator-updater==0.2.1
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1602859080374/work
# nbconvert @ file:///D:/bld/nbconvert_1605402041690/work
# nbdime @ file:///home/conda/feedstock_root/build_artifacts/nbdime_1601645814261/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1602732862338/work
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1605195931949/work
# networkx @ file:///home/conda/feedstock_root/build_artifacts/networkx_1598210780226/work
# nltk==3.4.4
# nose @ file:///home/conda/feedstock_root/build_artifacts/nose_1602434998960/work
# notebook @ file:///D:/bld/notebook_1605103957289/work
# numba @ file:///D:/bld/numba_1607010604208/work
# numexpr @ file:///D:/bld/numexpr_1602669959329/work
# numpy @ file:///D:/bld/numpy_1604946157939/work
# numpydoc @ file:///home/conda/feedstock_root/build_artifacts/numpydoc_1601580905698/work
# olefile @ file:///home/conda/feedstock_root/build_artifacts/olefile_1602866521163/work
# opencv-python==4.4.0.46
# openpyxl @ file:///home/conda/feedstock_root/build_artifacts/openpyxl_1598029012711/work
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1607785313469/work
# pandas @ file:///D:/bld/pandas_1607423802728/work
# pandas-profiling==2.9.0
# pandocfilters==1.4.2
# paramiko @ file:///home/conda/feedstock_root/build_artifacts/paramiko_1598988093657/work
# parso==0.7.0
# partd==1.1.0
# path @ file:///D:/bld/path_1607461645375/work
# pathlib2 @ file:///D:/bld/pathlib2_1604234378806/work
# pathspec @ file:///home/conda/feedstock_root/build_artifacts/pathspec_1605120834673/work
# pathtools==0.1.2
# patsy==0.5.1
# pdfminer.six @ file:///home/conda/feedstock_root/build_artifacts/pdfminer.six_1603029322483/work
# pep8==1.7.1
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1602535608087/work
# phik==0.10.0
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow @ file:///D:/bld/pillow_1604748918199/work
# pkginfo @ file:///home/conda/feedstock_root/build_artifacts/pkginfo_1603792998002/work
# plac==1.1.3
# plotly @ file:///home/conda/feedstock_root/build_artifacts/plotly_1607525005664/work
# pluggy @ file:///D:/bld/pluggy_1603384471261/work
# ply==3.11
# poyo==0.5.0
# preshed @ file:///D:/bld/preshed_1607337932670/work
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1605543085815/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1605053337398/work
# psutil @ file:///D:/bld/psutil_1603571190351/work
# ptyprocess==0.6.0
# py @ file:///home/conda/feedstock_root/build_artifacts/py_1607783655754/work
# pycodestyle==2.6.0
# pycosat @ file:///D:/bld/pycosat_1602278156974/work
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1593275161868/work
# pycryptodome @ file:///D:/bld/pycryptodome_1605190195816/work
# pycurl==7.43.0.6
# pydocstyle @ file:///home/conda/feedstock_root/build_artifacts/pydocstyle_1598747747227/work
# pydotplus==2.0.2
# pyerfa @ file:///D:/bld/pyerfa_1606601230540/work
# pyflakes==2.2.0
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1607352093725/work
# pylint==2.5.3
# pyls-black @ file:///home/conda/feedstock_root/build_artifacts/pyls-black_1595615126037/work
# pyls-spyder @ file:///home/conda/feedstock_root/build_artifacts/pyls-spyder_1607739452833/work
# PyNaCl @ file:///D:/bld/pynacl_1602614393605/work
# pyodbc @ file:///D:/bld/pyodbc_1602326935563/work
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1606535649775/work
# pyparsing==2.4.7
# PyPDF2==1.26.0
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyreadline @ file:///D:/bld/pyreadline_1602253139225/work
# pyrsistent @ file:///D:/bld/pyrsistent_1605115827510/work
# PySocks @ file:///D:/bld/pysocks_1602327034683/work
# pytest==6.2.0
# pytest-runner==5.2
# python-dateutil==2.8.1
# python-jsonrpc-server @ file:///home/conda/feedstock_root/build_artifacts/python-jsonrpc-server_1599827444631/work
# python-language-server @ file:///home/conda/feedstock_root/build_artifacts/python-language-server_1607720213724/work
# python-slugify @ file:///home/conda/feedstock_root/build_artifacts/python-slugify_1593573453419/work
# pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1604321279890/work
# PyWavelets @ file:///D:/bld/pywavelets_1607290958158/work
# pywin32==228
# pywin32-ctypes @ file:///D:/bld/pywin32-ctypes_1602283347259/work
# pywinpty @ file:///D:/bld/pywinpty_1602377663724/work
# PyYAML==5.3.1
# pyzmq==20.0.0
# QDarkStyle @ file:///home/conda/feedstock_root/build_artifacts/qdarkstyle_1604882576864/work
# QtAwesome @ file:///home/conda/feedstock_root/build_artifacts/qtawesome_1607463875213/work
# qtconsole @ file:///home/conda/feedstock_root/build_artifacts/qtconsole_1606282365040/work
# QtPy==1.9.0
# regex @ file:///D:/bld/regex_1605271080226/work
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1605186911681/work
# retrying==1.3.3
# rope @ file:///home/conda/feedstock_root/build_artifacts/rope_1602094471915/work
# Rtree @ file:///D:/bld/rtree_1605197196908/work
# ruamel-yaml-conda @ file:///D:/bld/ruamel_yaml_1602430512995/work
# s3transfer==0.3.3
# scikit-image==0.17.2
# scikit-learn @ file:///D:/bld/scikit-learn_1605985921978/work
# scipy @ file:///C:/bld/scipy_1604304921792/work
# seaborn @ file:///home/conda/feedstock_root/build_artifacts/seaborn-base_1604238753550/work
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch @ file:///home/conda/feedstock_root/build_artifacts/singledispatch_1602339038283/work
# sip==4.19.24
# six==1.15.0
# smart-open==2.1.0
# smmap @ file:///home/conda/feedstock_root/build_artifacts/smmap_1588651577140/work
# snowballstemmer==2.0.0
# sortedcollections @ file:///home/conda/feedstock_root/build_artifacts/sortedcollections_1591583091437/work
# sortedcontainers @ file:///home/conda/feedstock_root/build_artifacts/sortedcontainers_1605110889605/work
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1597680516047/work
# spacy @ file:///D:/bld/spacy_1606374929656/work
# speedtest-cli==2.1.2
# Sphinx @ file:///home/conda/feedstock_root/build_artifacts/sphinx_1607535079379/work
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==1.0.3
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.4
# sphinxcontrib-websupport @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-websupport_1597058540894/work
# spyder @ file:///D:/bld/spyder_1605144718345/work
# spyder-kernels @ file:///D:/bld/spyder-kernels_1605128760227/work
# SQLAlchemy @ file:///D:/bld/sqlalchemy_1602547238743/work
# srsly @ file:///D:/bld/srsly_1607347939729/work
# statsmodels @ file:///D:/bld/statsmodels_1604227114522/work
# sympy @ file:///D:/bld/sympy_1607832374684/work
# tables==3.6.1
# tangled-up-in-unicode==0.0.6
# tblib==1.6.0
# terminado @ file:///D:/bld/terminado_1605117138129/work
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# thinc @ file:///D:/bld/thinc_1607425343367/work
# threadpoolctl @ file:///tmp/tmp79xdzxkt/threadpoolctl-2.1.0-py3-none-any.whl
# three-merge @ file:///home/conda/feedstock_root/build_artifacts/three-merge_1595515817927/work
# tifffile @ file:///home/conda/feedstock_root/build_artifacts/tifffile_1607552325200/work
# toml==0.10.1
# toolz @ file:///home/conda/feedstock_root/build_artifacts/toolz_1600973991856/work
# torch==1.7.0
# torchaudio==0.7.0
# torchvision==0.8.1
# tornado @ file:///D:/bld/tornado_1604105353952/work
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1607145891039/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1602771532708/work
# typed-ast @ file:///D:/bld/typed-ast_1604870864462/work
# typing-extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1602702424206/work
# ujson @ file:///D:/bld/ujson_1602282248660/work
# unicodecsv==0.14.1
# Unidecode==1.1.1
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1603125704209/work
# vboxapi==1.0
# visions==0.5.0
# wasabi @ file:///home/conda/feedstock_root/build_artifacts/wasabi_1600272362626/work
# watchdog @ file:///D:/bld/watchdog_1607631221861/work
# watermark==2.0.2
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webencodings==0.5.1
# Werkzeug==1.0.1
# whichcraft==0.6.1
# widgetsnbextension @ file:///D:/bld/widgetsnbextension_1605475695976/work
# win-inet-pton @ file:///D:/bld/win_inet_pton_1602260115377/work
# win-unicode-console @ file:///D:/bld/win_unicode_console_1603158644275/work
# wincertstore==0.2
# wordcloud==1.8.0
# wrapt==1.12.1
# xgboost==1.1.1
# xlrd @ file:///home/conda/feedstock_root/build_artifacts/xlrd_1595712200082/work
# XlsxWriter @ file:///home/conda/feedstock_root/build_artifacts/xlsxwriter_1602583799765/work
# xlwings @ file:///D:/bld/xlwings_1606135962571/work
# xlwt==1.3.0
# xmltodict==0.12.0
# yapf @ file:///home/conda/feedstock_root/build_artifacts/yapf_1595950469082/work
# zict==2.0.0
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1603668650351/work
# zope.event @ file:///home/conda/feedstock_root/build_artifacts/zope.event_1600479883063/work
# zope.interface @ file:///D:/bld/zope.interface_1605096210216/work

# %%
#pip install gunicorn
# Out:
# Requirement already satisfied: gunicorn in c:\programdata\anaconda3\lib\site-packages (20.0.4)
# Requirement already satisfied: setuptools>=3.0 in c:\programdata\anaconda3\lib\site-packages (from gunicorn) (49.6.0.post20201009)
# Note: you may need to restart the kernel to use updated packages.
